# %% [markdown]
# #### **Solve the folling questions:**
#
# ###**Exercise  4.3.1** Consider a particle in initial spin up. Apply Sx to it and determinethe probability that the resulting state is still spin up.
#
# ###**Exercise 4.3.2** Perform the same calculations as in the last example, using Exercise 4.3.1. Then draw the probability distribution of the eigenvalues as in the previous example.
#
# ###**Exercise 4.4.1** Verify that U1 =[[1,0],[0,-1]] and U2 = [[√2/2, √2/2], [√2/2, -√2/2]]
#
# ###**Exercise 4.4.2** Go back to Example 3.3.2 (quantum billiard ball), keep the same initial state vector [1, 0, 0, 0]T, but change the unitary map to [[0, 1/√2, 1/√2, 0],[i/√2, 0, 0, 1/√2],[1/√2, 0, 0, i/√2],[0, 1/√2, -1/√2, 0]]. Determine the state of the system after three time steps. What is the chance of the quantum ball to be found at point 3?

# %%
import math
import numpy as np
from numpy.linalg import eig
x = np.array([-3-1j,2j,1j,2])
y = np.array([5+10j,22-3j,5+1j,0])

def Probability_at_State(Array,Location):
    np.array(Array)
    denominator = np.linalg.norm(Array)**2
    Y = (np.linalg.norm(Array[Location])**2)/denominator
    return(str(float(Y*100))+"%")
def amplitud_vector(Array, Array_1):
    np.array(Array),np.array(Array_1)
    denominator = np.linalg.norm(Array)
    denominator_1 = np.linalg.norm(Array_1)
    Array = Array /denominator
    Array_div = Array_1 / denominator_1
    Array_div_conjugate = []
    for i in Array_div:
        b = np.conjugate(i)
        Array_div_conjugate.append(b)
    result = np.inner(Array, Array_div_conjugate)
    return result

def Probability_one_state_to_other(Array, Array_1):
    np.array(Array),np.array(Array_1)
    Probability_Array, Probability_Array_1 = [],[]
    for i in Array:
        Y = (np.linalg.norm(i)/np.linalg.norm(Array))**2
        Probability_Array.append(Y)
    for j in Array_1:
        Y = (np.linalg.norm(j)/np.linalg.norm(Array_1))**2
        Probability_Array_1.append(Y)
    tensor_dot = []
    pointer =[]
    count = 0
    for i in Probability_Array:
        count_1 = 0
        for j in Probability_Array_1:
            tensor_dot.append(i*j)
            pointer.append(str(count)+" "+str(count_1))
            count_1 = count_1 + 1
            print("The probability of moving from " +str(count)+" to "+str(count_1)+" is: "+str(i*j*100)+"%")
        count = + 1
    return
def Hermitian_mat(Array):
    M = np.transpose(Array)
    A = []
    for i in M:
        A.append(np.conjugate(i))
    if (np.array(A)).all() == (np.array(Array)).all():
        return True
    else:
        return False
def MeanandVariance(Array, Array_1):
    if Hermitian_mat(Array):
        pre_Media = np.multiply(Array_1,Array_1)
        Media = np.multiply(Array,pre_Media)
        print(Media)
        Array_2 = (Array - (Media @(np.eye(len(Array)))))**2
        return ("The variace is : " + str(Array_2 * Array_1))
    else:
        return "The matrix is nor hermitian. It is not posible to return it's variance"


def EigenValuesProbability(Array, Array_1):
    print(np.linalg.eig(Array))
    Probability_one_state_to_other(Array, Array_1)
    return
def FinalState(Unitary,t):
    #assuming that the matrix is unitary and there is no obserbable we can use this function
    if len(Unitary) == t:
        Final_State = []
        time = 0
        for i in Unitary:
            result = i * time
            Final_State.append(result)
            time = time + 0
        r = 1
        for i in Final_State:
            r = r * i
        return r
    else:
        return("Check that your using the right amount of time or that your using the right amount of variables on the Un")
print("Question #1 or 4.3.1")
EigenValuesProbability([[1.05e-35, 0],[0, -1.05e-35]],[1,0])
print("")
print("Question #2 or 4.3.2")
MeanandVariance([[1.05e-35, 0],[0, -1.05e-35]],[1,0])
print("")
print("Question #3 or 4.4.1")
print("If the matrix is hermitian it will return true, other wize it will return false")
print("Say if it is true or false that the matrix [[1,0],[0,1]] is hermitian.")
print(Hermitian_mat([[1,0],[0,1]]))
print("Say if it is true or false that the matrix [[√2/2, √2/2], [√2/2, -√2/2]]is hermitian.")
print(Hermitian_mat([[math.sqrt(2)/2,math.sqrt(2)/2],[math.sqrt(2)/2,-math.sqrt(2)/2]]))
Ro = [[1,0],[0,1]]
Run = [[math.sqrt(2)/2,math.sqrt(2)/2],[math.sqrt(2)/2,-math.sqrt(2)/2]]
Mat = np.multiply(Ro,Run)
print("Say if it is true or false that the matrix "+ str(Mat)+" is hermitian.")
print(Hermitian_mat(Mat))
print("")
print("Question #4 or 4.4.2")
print("The probability of finding the matrix [[0, 1/√2, 1/√2, 0],[i/√2, 0, 0, 1/√2],[1/√2, 0, 0, i/√2],[0, 1/√2, -1/√2, 0]] at point number 3 is:")
a = [[0, 1/math.sqrt(2), 1/math.sqrt(2), 0],[1j/math.sqrt(2), 0, 0, 1/math.sqrt(2)],[1/math.sqrt(2), 0, 0, 1j/math.sqrt(2)],[0, 1/math.sqrt(2), 1/math.sqrt(2), 0]]
State_1 = np.multiply(a,[1,0,0,0])
State_2 = np.multiply(a,State_1)
State_3 = np.multiply(a,State_2)
print(State_3[2])
# Out:
# Question #1 or 4.3.1
# EigResult(eigenvalues=array([ 1.05e-35, -1.05e-35]), eigenvectors=array([[1., 0.],
#        [0., 1.]]))
# The probability of moving from 0 to 1 is: 49.999999999999986%
# The probability of moving from 0 to 2 is: 0.0%
# The probability of moving from 1 to 1 is: 49.999999999999986%
# The probability of moving from 1 to 2 is: 0.0%
#
# Question #2 or 4.3.2
# [[ 1.05e-35  0.00e+00]
#  [ 0.00e+00 -0.00e+00]]
#
# Question #3 or 4.4.1
# If the matrix is hermitian it will return true, other wize it will return false
# Say if it is true or false that the matrix [[1,0],[0,1]] is hermitian.
# True
# Say if it is true or false that the matrix [[√2/2, √2/2], [√2/2, -√2/2]]is hermitian.
# True
# Say if it is true or false that the matrix [[ 0.70710678  0.        ]
#  [ 0.         -0.70710678]] is hermitian.
# True
#
# Question #4 or 4.4.2
# ...

# %% [markdown]
# ###**Exercise 4.5.1** Redo the steps of the last example when n = m = 4 and c0,0 =
# c0,1 =···= c3,3 = 1 + i.
#
#
# In this point we are supposed to find the probability of finding both particles together at x1.
#
#
# The way that we should do this is by finding the magnitud of x1 and normalizing the rest of the particles. Then we would operate Magnitud /normalized sum.
#
# What this means is that the particle in stage x1 nomalized of 1 + i is √2 since what we do is , take the sqrt(1^2 + 1^2). Then we would square this. The result is (sqrt(1^2 + 1^2))^2 = (2).
#
# So we have 4 particles and they are all the same, 1 + i.
#
# The normalized form is sqrt(sqrt(2)^2+sqrt(2)^2+sqrt(2)^2+sqrt(2)^2) = 8
#
# then we should take 2 / 8 and we get 0.25.
#
# The answer is 0.25
